# %%
# !pip install langchain-groq -q
# !pip install -qU langchain-google-genai
# !pip install langchain langchain-community faiss-cpu tiktoken -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 82.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 60.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.

# %%
import os

os.environ["GROQ_API_KEY"]   = "Mine is hidden for privacy after running the cell"
os.environ["GOOGLE_API_KEY"] = "Mine is hidden for privacy after running the cell"

print("Keys set.")
# Out:
# Keys set.

# %% [markdown]
# # **Core Components of LangChain**

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
import os

# Step 1: Creating the model
model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# Step 2: Create prompt template
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms"
)

# Step 3: Create chain
chain = prompt | model

# Step 4: Run chain
response = chain.invoke({"topic": "neural networks"})
print(response.content)
# Out:
# **What is a Neural Network.**
# A neural network is a computer system that works like the human brain. It's made up of many interconnected nodes (called "neurons") that process and transmit information.
#
# **How it Works:**
# 1. **Input**: The network receives data, like images or sounds.
# 2. **Processing**: The data is sent through multiple layers of neurons, which analyze and transform it.
# 3. **Output**: The final layer produces a result, like a prediction or classification.
#
# **Key Concepts:**
#
# * **Artificial Neurons**: These are the basic building blocks of the network. They receive input, perform a calculation, and send the result to other neurons.
# * **Layers**: Neural networks are organized into layers, each with its own role (e.g., input, hidden, output).
# * **Connections**: Neurons are connected, allowing them to exchange information.
# * **Training**: The network learns from data by adjusting the connections between neurons.
#
# **Simple Analogy:**
# Imagine a team of experts working together to make a decision. Each expert (neuron) looks at the data, makes a judgment, and shares their findings with the others. The team (network) combines these judgments to produce a final answer.
#
# **Real-World Applications:**
# Neural networks are used in many areas, including:
#
# * Image recognition
# * Speech recognition
# * Natural language processing
# * Predictive modeling
# * Self-driving cars
#
# In summary, neural networks are powerful computer systems that mimic the human brain's ability to learn and make decisions. They're composed of interconnected nodes that process and transmit information, and are trained on data to produce accurate results.

# %% [markdown]
# Templating

# %% [markdown]
# #### Basic PromptTemplate

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

formatted_prompt = template.format(topic="Langchain")

print(formatted_prompt)
# Out:
# Explain Langchain in simple terms

# %% [markdown]
# #### ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("user", "Explain {topic} simply")
])

# format_messages() returns a list of Message objects ready to send
messages = chat_template.format_messages(topic="Human Brain")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Human Brain simply', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# #### Few-Shot Prompt Templates

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate
from langchain_groq import ChatGroq
import os

os.environ["GROQ_API_KEY"] = "Mine is hidden for privacy after running the cell"

# Step 1: Define examples
examples = [
    {"input": "I love this movie", "output": "Positive"},
    {"input": "This is terrible", "output": "Negative"},
    {"input": "Amazing experience", "output": "Positive"},
]

# Step 2: Example prompt template
example_prompt = PromptTemplate(
    input_variables=["input", "output"],
    template="Text: {input}\nSentiment: {output}"
)

# Step 3: Few-shot prompt template
few_shot_prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=example_prompt,
    prefix="Classify the sentiment of the following text:\n\n",
    suffix="Text: {input}\nSentiment:",
    input_variables=["input"]
)

# Step 4: Create model
model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# Step 5: Create chain and invoke
chain = few_shot_prompt | model

response = chain.invoke({"input": "This product is amazing"})

print(response.content)
# Out:
# Positive

# %% [markdown]
# ## Type of Prompt Template

# %% [markdown]
# #### Basic PromptTemplate + LLM

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

chain = prompt | model

response = chain.invoke({"topic": "XG Boost"})

print(response.content)
# Out:
# **XG Boost Overview**
# ===============
#
# XG Boost (Extreme Gradient Boosting) is a popular, open-source, machine learning algorithm used for classification and regression tasks. It's an extension of the Gradient Boosting algorithm, which combines multiple weak models to create a strong predictive model.
#
# **Key Components**
# ----------------
#
# 1. **Decision Trees**: XG Boost uses decision trees as the base models. Each tree is a simple model that splits data into subsets based on features.
# 2. **Gradient Boosting**: The algorithm combines multiple decision trees to create a strong model. Each subsequent tree tries to correct the errors of the previous tree.
# 3. **Regularization**: XG Boost includes regularization techniques to prevent overfitting, such as L1 and L2 regularization.
#
# **How XG Boost Works**
# ---------------------
#
# 1. **Initialize**: Start with an initial model (usually a simple decision tree).
# 2. **Calculate Errors**: Calculate the errors between the predicted values and the actual values.
# 3. **Create New Tree**: Create a new decision tree that tries to correct the errors of the previous tree.
# 4. **Combine Trees**: Combine the new tree with the previous trees to create a stronger model.
# 5. **Repeat**: Repeat steps 2-4 until a stopping criterion is reached (e.g., a maximum number of trees or a minimum error threshold).
#
# **Advantages**
# ------------
#
# 1. **High Accuracy**: XG Boost often achieves high accuracy in classification and regression tasks.
# 2. **Handling Missing Values**: XG Boost can handle missing values in the data.
# 3. **Parallelization**: XG Boost can be parallelized, making it suitable for large datasets.
#
# **Common Applications**
# ---------------------
#
# 1. **Classification**: XG Boost is often used for classification tasks, such as spam detection, sentiment analysis, and image classification.
# 2. **Regression**: XG Boost can be used for regression tasks, such as predicting continuous values (e.g., stock prices, temperatures).
# 3. **Feature Selection**: XG Boost can be used for feature selection, as it provides feature importance scores.
#
# **Example Use Case**
# -------------------
#
# Suppose we want to predict whether a customer will buy a product based on their demographic data (age, income, location). We can use XG Boost to train a model on a labeled dataset, where each sample represents a customer, and the target variable is a binary label (0 = did not buy, 1 = bought). The XG Boost model can learn the complex relationships between the demographic features and the target variable, providing a high-accuracy prediction model.

# %% [markdown]
# ChatPromptTemplate Example

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# Step 1: Create model
model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# Step 2: Create chat prompt
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a teacher"),
    ("user", "Explain {topic} with examples")
])

# Step 3: Create chain
chain = chat_prompt | model

# Step 4: Invoke
response = chain.invoke({"topic": "overfitting"})

print(response.content)
# Out:
# Overfitting is a fundamental concept in machine learning and statistics that occurs when a model is too complex and learns the noise in the training data, rather than the underlying patterns. This results in a model that performs well on the training data but poorly on new, unseen data.
#
# **What is overfitting?**
#
# Overfitting happens when a model is too closely fit to the training data, capturing the random fluctuations and noise in the data rather than the underlying relationships. As a result, the model becomes overly specialized to the training data and fails to generalize well to new data.
#
# **Example 1: Polynomial Regression**
#
# Suppose we want to model the relationship between the number of hours studied and the exam score. We collect data from 10 students and fit a polynomial regression model of degree 9 (a 9th-degree polynomial). The model fits the training data perfectly, but when we test it on new data, it performs poorly.
#
# Training data:
#
# | Hours Studied | Exam Score |
# | --- | --- |
# | 2 | 80 |
# | 4 | 90 |
# | 6 | 95 |
# | 8 | 92 |
# | 10 | 88 |
# | 12 | 85 |
# | 14 | 82 |
# | 16 | 80 |
# | 18 | 78 |
# | 20 | 75 |
#
# The 9th-degree polynomial model fits the training data perfectly, but it's clear that the model is overfitting. The model is too complex and is capturing the random fluctuations in the data rather than the underlying relationship.
#
# **Example 2: Image Classification**
#
# Suppose we're training a neural network to classify images as either "cats" or "dogs". We collect a dataset of 1000 images, 500 of which are cats and 500 of which are dogs. We train a neural network with 1000 layers, and it achieves 100% accuracy on the training data. However, when we test it on new, unseen data, it performs poorly, achieving only 50% accuracy.
#
# In this case, the neural network is overfitting the training data. The model is too complex and is learning the specific features of the training images, rather than the general features that distinguish cats from dogs.
#
# **Example 3: Decision Trees**
#
# Suppose we're training a decision tree to predict whether a customer will buy a product based on their age, income, and location. We collect a dataset of 100 customers and train a decision tree with 100 nodes. The decision tree fits the training data perfectly, but when we test it on new data, it performs poorly.
#
# In this case, the decision tree is overfitting the training data. The model is too complex and is learning the specific patterns in the training data, rather than the underlying relationships between the variables.
#
# **How to prevent overfitting?**
#
# There are several techniques to prevent overfitting, including:
#
# 1. **Regularization**: Adding a penalty term to the loss function to discourage large weights.
# 2. **Early stopping**: Stopping the training process when the model's performance on the validation set starts to degrade.
# 3. **Data augmentation**: Increasing the size of the training dataset by applying random transformations to the existing data.
# 4. **Dropout**: Randomly dropping out neurons during training to prevent the model from relying too heavily on any one neuron.
# 5. **Simplifying the model**: Reducing the complexity of the model by removing layers or neurons.
#
# By understanding overfitting and using these techniques, we can develop models that generalize well to new data and make accurate predictions.

# %% [markdown]
# # Models

# %% [markdown]
# ## LLM Example

# %%
from langchain_groq import ChatGroq
import os
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

response = llm.invoke("Explain machine learning in simple terms")

print(response.content)
# Out:
# **Machine Learning in Simple Terms**
#
# Machine learning is a way to teach computers to make decisions or predictions based on data, without being explicitly programmed. It's like teaching a child to recognize objects, but instead of using words, you show them many examples.
#
# **How it Works:**
#
# 1. **Data Collection**: Gather lots of data, like images, text, or numbers.
# 2. **Pattern Recognition**: Use algorithms (like recipes) to find patterns in the data.
# 3. **Learning**: The computer uses these patterns to make predictions or decisions.
# 4. **Improvement**: The more data the computer sees, the better it becomes at making accurate predictions.
#
# **Example:**
#
# Imagine you want to teach a computer to recognize pictures of cats and dogs. You show it many pictures of cats and dogs, and it starts to notice patterns, like:
#
# * Cats have pointy ears and whiskers.
# * Dogs have floppy ears and tails.
#
# The computer uses these patterns to make predictions: "This picture is a cat" or "This picture is a dog." The more pictures it sees, the better it becomes at recognizing cats and dogs.
#
# **Types of Machine Learning:**
#
# 1. **Supervised Learning**: The computer is shown labeled data (e.g., "this is a cat") and learns to make predictions.
# 2. **Unsupervised Learning**: The computer finds patterns in unlabeled data (e.g., grouping similar objects together).
# 3. **Reinforcement Learning**: The computer learns by trial and error, receiving rewards or penalties for its actions.
#
# **Real-World Applications:**
#
# 1. Image recognition (e.g., self-driving cars)
# 2. Speech recognition (e.g., virtual assistants)
# 3. Predictive maintenance (e.g., predicting equipment failures)
# 4. Personalized recommendations (e.g., product suggestions)
#
# Machine learning is a powerful tool that helps computers make sense of complex data and make informed decisions.

# %% [markdown]
# ## Chat Model Example

# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_groq import ChatGroq

chat_model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

message = [
    SystemMessage(content= 'You are a helpful Sr Data Scientist.'),
    HumanMessage(content ='Explain how to get a job')
]

response = chat_model.invoke(message)

print(response.content)
# Out:
# Getting a job can be a challenging and competitive process, but with a strategic approach, you can increase your chances of success. Here's a step-by-step guide to help you get a job:
#
# **Step 1: Define Your Job Search Goals**
#
# 1. Identify the type of job you're looking for (industry, role, location, etc.).
# 2. Update your career goals and job preferences.
# 3. Consider what you're looking for in a job (salary, work-life balance, company culture, etc.).
#
# **Step 2: Update Your Resume and Online Profiles**
#
# 1. **Resume:**
# 	* Tailor your resume to the job you're applying for.
# 	* Highlight your relevant skills, experience, and achievements.
# 	* Use a clear and concise format.
# 2. **Online Profiles:**
# 	* Update your LinkedIn profile to match your resume.
# 	* Ensure your other social media profiles are professional and consistent with your personal brand.
#
# **Step 3: Networking and Job Search Platforms**
#
# 1. **Networking:**
# 	* Reach out to friends, family, and colleagues to let them know you're job searching.
# 	* Attend industry events, conferences, and job fairs.
# 	* Connect with people on LinkedIn and engage with their content.
# 2. **Job Search Platforms:**
# 	* Utilize job boards like LinkedIn, Indeed, Glassdoor, and Monster.
# 	* Set up job alerts to receive notifications about new job postings.
# 	* Explore company websites and career pages.
#
# **Step 4: Apply for Jobs**
#
# 1. **Job Application:**
# 	* Customize your application materials (resume, cover letter, etc.) for each job.
# 	* Ensure you meet the job requirements and qualifications.
# 	* Submit your application through the designated channel (online portal, email, etc.).
# 2. **Follow-up:**
# 	* Send a follow-up email or message to confirm receipt of your application.
# 	* Reiterate your interest in the position and ask about the status of your application.
#
# **Step 5: Prepare for Interviews**
#
# 1. **Research:**
# 	* Learn about the company, its products/services, mission, and values.
# 	* Review the job description and requirements.
# 2. **Practice:**
# 	* Prepare answers to common interview questions.
# 	* Practice your responses with a friend or family member.
# 3. **Logistics:**
# 	* Plan your outfit, transportation, and arrival time.
# 	* Bring multiple copies of your resume and any other requested documents.
#
# **Step 6: Ace the Interview**
#
# 1. **First Impressions:**
# 	* Make a strong first impression with your attire, body language, and greeting.
# 2. **Answer Questions:**
# 	* Be honest, concise, and specific in your responses.
# 	* Show enthusiasm and interest in the company and role.
# 3. **Ask Questions:**
# 	* Prepare thoughtful questions to ask the interviewer.
# 	* Demonstrate your knowledge and curiosity about the company and position.
#
# **Step 7: Follow-up and Negotiation**
#
# 1. **Thank-you Note:**
# 	* Send a thank-you note or email to express gratitude for the interview.
# 	* Reiterate your interest in the position.
# 2. **Job Offer:**
# 	* Carefully review the job offer and its terms.
# 	* Negotiate salary, benefits, or other aspects of the offer if necessary.
# 3. **Acceptance:**
# 	* Accept the job offer and confirm the details.
# 	* Start preparing for your new role and onboarding process.
#
# Remember, getting a job is a process that takes time, effort, and perseverance. Stay positive, be proactive, and continuously improve your skills and knowledge to increase your chances of success.

# %% [markdown]
# ### Embedding Example

# %%
# !pip install -qU langchain-google-genai

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

vector = embeddings.embed_query("machine learning")

print(vector[:5])
# Out:
# [-0.006826791, 0.0032323739, 0.0036080698, -0.063535206, -0.016612697]

# %%
vec1 = embeddings.embed_query("cat")
print(vec1[:5])
# Out:
# [-0.017016973, 0.011458129, 0.022643944, -0.070259035, -0.0046942607]

# %%
vec2 = embeddings.embed_query("dog")
print(vec2[:5])
# Out:
# [-0.0152275665, -0.013213994, 0.028866338, -0.06026992, -0.014451638]

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity([vec1], [vec2])
print(similarity)
# Out:
# [[0.74689359]]

# %% [markdown]
# Output Parser

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_groq import ChatGroq

parser = JsonOutputParser()

model = ChatGroq(model="llama-3.3-70b-versatile")

response = model.invoke("Return name and age in JSON format")

parsed_output = parser.invoke(response)
print(parsed_output)
# Out:
# {'name': 'John Doe', 'age': 30}

# %% [markdown]
# # Section 4: Hands-on Code Examples

# %% [markdown]
# **Basic LLM Call**

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# Step 1: Create model
# temperature=0 → deterministic, factual output
model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# Step 2: Create prompt template
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms"
)

# Step 3: Create chain using LCEL pipe operator
chain = prompt | model

# Step 4: Run chain — response is an AIMessage object
response = chain.invoke({"topic": "neural networks"})

print(response.content)
# Out:
# **What is a Neural Network.**
# A neural network is a computer system that works like the human brain. It's made up of many connected "neurons" (or nodes) that process and share information.
#
# **How it Works:**
# 1. **Input**: The network receives information, like images, sounds, or text.
# 2. **Processing**: The information is passed through multiple layers of neurons, which analyze and transform it.
# 3. **Output**: The final layer produces a result, like a prediction or a decision.
#
# **Key Concepts:**
#
# * **Artificial Neurons**: These are the building blocks of the network. They receive input, perform calculations, and send output to other neurons.
# * **Connections**: Neurons are connected to each other, allowing them to share information.
# * **Layers**: The network is organized into layers, each with its own role (e.g., input, processing, output).
# * **Training**: The network learns from data by adjusting the connections between neurons to improve its performance.
#
# **Simple Analogy:**
# Imagine a team of experts working together to make a decision. Each expert (neuron) looks at the information, discusses it with others, and contributes to the final decision. The team (network) learns from experience and improves its decision-making over time.
#
# **Real-World Applications:**
# Neural networks are used in many areas, such as:
#
# * Image recognition (e.g., self-driving cars)
# * Speech recognition (e.g., virtual assistants)
# * Natural language processing (e.g., chatbots)
# * Predictive modeling (e.g., stock market forecasting)
#
# In summary, neural networks are powerful computer systems that mimic the human brain's ability to learn and make decisions. They're composed of connected neurons that process and share information, and they have many practical applications in various fields.

# %% [markdown]
# **Simple Chain**

# %% [markdown]
# Simple Chain Example

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

prompt = ChatPromptTemplate.from_template("Explain {topic} simply")

model = ChatGroq(model="llama-3.3-70b-versatile")

chain = prompt | model

response = chain.invoke({"topic": "Gen AI"})
print(response.content)
# Out:
# Gen AI, also known as General Artificial Intelligence, refers to a type of artificial intelligence that can perform any intellectual task that a human can. It's like a super-smart computer that can learn, reason, and apply knowledge across a wide range of tasks, just like a human.
#
# Think of it like this: current AI systems are like specialized tools, each designed to do one specific job, like playing chess or recognizing faces. Gen AI, on the other hand, is like a universal tool that can do many jobs, and even learn to do new ones on its own.
#
# Gen AI has the potential to revolutionize many areas of life, from healthcare and education to transportation and entertainment. However, it's still a developing field, and researchers are working to create Gen AI systems that are safe, reliable, and beneficial to society.
#
# Here are some key features of Gen AI:
#
# 1. **General-purpose**: Can perform many tasks, not just one specific job.
# 2. **Learning**: Can learn from experience and adapt to new situations.
# 3. **Reasoning**: Can make decisions and solve problems using logic and evidence.
# 4. **Knowledge**: Can acquire and apply knowledge across many domains.
#
# While we're not yet at the level of true Gen AI, researchers are making rapid progress, and many experts believe that we'll see significant advancements in the coming years.

# %% [markdown]
# **LCEL Example — Full Pipeline with Output Parser (Most Important)**

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt | model | StrOutputParser()

result = chain.invoke({"topic": "Machine Learning"})
print(result)
# Out:
# **Machine Learning in Simple Terms**
#
# Machine Learning is a way to teach computers to make decisions or predictions based on data, without being explicitly programmed. It's like teaching a child to recognize objects, but instead of using words, you show them many examples.
#
# **How it Works:**
#
# 1. **Data Collection**: Gather lots of data, like images, text, or numbers.
# 2. **Training**: Show the computer many examples from the data, and tell it what the correct answer is.
# 3. **Learning**: The computer finds patterns and relationships in the data, and creates a model to make predictions.
# 4. **Prediction**: Use the model to make predictions on new, unseen data.
#
# **Example:**
#
# * You want to teach a computer to recognize pictures of dogs and cats.
# * You collect many pictures of dogs and cats, and label them as "dog" or "cat".
# * The computer looks at the pictures, finds patterns (like ears, whiskers, and fur), and creates a model to recognize dogs and cats.
# * When you show the computer a new picture, it uses the model to predict whether it's a dog or a cat.
#
# **Types of Machine Learning:**
#
# 1. **Supervised Learning**: The computer is trained on labeled data, like the dog and cat example.
# 2. **Unsupervised Learning**: The computer finds patterns in unlabeled data, like grouping similar customers.
# 3. **Reinforcement Learning**: The computer learns by trying different actions and getting rewards or penalties.
#
# **Real-World Applications:**
#
# 1. Image recognition (e.g., self-driving cars)
# 2. Speech recognition (e.g., virtual assistants)
# 3. Recommendation systems (e.g., Netflix suggestions)
# 4. Predictive maintenance (e.g., predicting equipment failures)
#
# Machine Learning is a powerful tool that can help computers make decisions, predictions, and recommendations, making our lives easier and more efficient.

# %% [markdown]
# **Memoey Example**

# %%
# !pip install langchain-groq -q
# !pip install -qU langchain-google-genai
# !pip install langchain langchain-community faiss-cpu tiktoken -q

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage

model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# Modern memory — plain list holds the full conversation history
chat_history = []

# MessagesPlaceholder injects the full history into every prompt automatically
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{input}")
])

chain = prompt | model

def chat(user_input):
    # Store user message
    chat_history.append(HumanMessage(content=user_input))
    # Run chain with full history injected
    response = chain.invoke({
        "input": user_input,
        "chat_history": chat_history
    })
    # Store AI reply
    chat_history.append(AIMessage(content=response.content))
    return response.content

# Turn 1: introduce name
r1 = chat("Hi! My name is Nikitha. I am a Gen AI intern at Innomatics.")
print("Turn 1:", r1)

# Turn 2: ask something unrelated
r2 = chat("What is NLP?")
print("\nTurn 2:", r2)

# Turn 3: memory test — model should remember the name
r3 = chat("What is my name and where do I intern?")
print("\nTurn 3 (memory test):", r3)

# See what is stored in memory
print("\n--- Memory Buffer ---")
for msg in chat_history:
    role = "Human" if isinstance(msg, HumanMessage) else "AI"
    print(f"[{role}]: {msg.content[:120]}")
# Out:
# Turn 1: Hello Nikitha, nice to meet you. Congratulations on your internship at Innomatics. How's your experience with Gen AI so far? What kind of projects are you working on?
#
# Turn 2: NLP stands for Natural Language Processing. It's a subfield of artificial intelligence (AI) that deals with the interaction between computers and humans in natural language. The goal of NLP is to enable computers to understand, interpret, and generate human language, such as text or speech.
#
# NLP involves a range of tasks, including:
#
# 1. **Text analysis**: extracting meaning and insights from text data, such as sentiment analysis, entity recognition, and topic modeling.
# 2. **Language understanding**: enabling computers to comprehend the meaning of text or speech, including syntax, semantics, and pragmatics.
# 3. **Language generation**: generating human-like text or speech, such as chatbots, language translation, and text summarization.
# 4. **Speech recognition**: converting spoken language into text, such as voice assistants and speech-to-text systems.
#
# NLP has many applications, including:
#
# 1. Virtual assistants (e.g., Siri, Alexa)
# 2. Language translation software
# 3. Sentiment analysis and opinion mining
# 4. Chatbots and customer service platforms
# 5. Text summarization and document analysis
#
# As a Gen AI intern, you might be working on NLP-related projects, such as developing language models, fine-tuning pre-trained models, or exploring NLP applications in various domains. Is that correct, Nikitha?
#
# Turn 3 (memory test): Your name is Nikitha, and you intern at Innomatics as a Gen AI intern.
#
# --- Memory Buffer ---
# [Human]: Hi! My name is Nikitha. I am a Gen AI intern at Innomatics.
# [AI]: Hello Nikitha, nice to meet you. Congratulations on your internship at Innomatics. How's your experience with Gen AI so
# [Human]: What is NLP?
# [AI]: NLP stands for Natural Language Processing. It's a subfield of artificial intelligence (AI) that deals with the interact
# [Human]: What is my name and where do I intern?
# [AI]: Your name is Nikitha, and you intern at Innomatics as a Gen AI intern.

# %% [markdown]
# **Agent with Tool**

# %%
# !pip install langchain -q
# !pip install langgraph -q

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
from langgraph.prebuilt import create_react_agent

model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# ------------------------------------------------------------------ #
# Define tools using the @tool decorator                              #
# The docstring is what the agent reads to decide when to use it      #
# ------------------------------------------------------------------ #

@tool
def calculate_bmi(weight_kg: float, height_m: float) -> str:
    """Calculate Body Mass Index (BMI) given weight in kg and height in meters."""
    bmi = weight_kg / (height_m ** 2)
    if bmi < 18.5:
        category = "Underweight"
    elif bmi < 25:
        category = "Normal weight"
    elif bmi < 30:
        category = "Overweight"
    else:
        category = "Obese"
    return f"BMI: {bmi:.2f} — Category: {category}"


@tool
def celsius_to_fahrenheit(celsius: float) -> str:
    """Convert a temperature value from Celsius to Fahrenheit."""
    fahrenheit = (celsius * 9 / 5) + 32
    return f"{celsius}°C = {fahrenheit:.1f}°F"


tools = [calculate_bmi, celsius_to_fahrenheit]

# langgraph's create_react_agent handles the ReAct loop internally
# no manual PromptTemplate needed — just pass model + tools
agent = create_react_agent(model=model, tools=tools)

# Run the agent
result = agent.invoke({
    "messages": [
        ("human", "What is the BMI of someone who weighs 41 kg and is 156 cm tall? Also convert 37 Celsius to Fahrenheit.")
    ]
})

print("\n=== Final Answer ===")
print(result["messages"][-1].content)
# Out:
# /tmp/ipykernel_3751/105099922.py:38: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(model=model, tools=tools)
# === Final Answer ===
# The BMI of someone who weighs 41 kg and is 156 cm tall is 16.85, which falls under the underweight category. The temperature 37 Celsius is equivalent to 98.6 Fahrenheit.

# %% [markdown]
# **Document Loaders & Vector Stores (RAG Pipeline)**

# %%
# !pip install langchain-text-splitters -q

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter  # ← only this line changed

raw_documents = [
    Document(page_content="""
        LangChain is an open-source framework for building LLM-powered applications.
        It was created by Harrison Chase and first released in October 2022.
        LangChain provides tools for chaining prompts, managing memory, building
        agents, and connecting LLMs to external data sources and vector stores.
    """, metadata={"source": "langchain_intro.txt"}),

    Document(page_content="""
        Numpy is ais a core Python library used for fast mathematical operations on arrays and matrices.
         NumPy is important because it is faster than normal Python lists,used in Data Science, AI, ML base for libraries like Pandas, TensorFlow
    """, metadata={"source": "pythin_info.txt"}),

    Document(page_content="""
        RAG stands for Retrieval-Augmented Generation. In a RAG pipeline, the user
        query is embedded and used to search a vector store for the most relevant
        document chunks. Those chunks are injected into the LLM prompt as context,
        allowing the model to answer questions grounded in real retrieved text,
        which significantly reduces hallucinations.
    """, metadata={"source": "rag_explained.txt"}),
]

print(f"Loaded {len(raw_documents)} documents.")

splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=50
)

chunks = splitter.split_documents(raw_documents)
print(f"Split into {len(chunks)} chunks.")
# Out:
# Loaded 3 documents.
# Split into 5 chunks.

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

vector_store = FAISS.from_documents(chunks, embeddings)

print("Vector store built successfully.")
print(f"Total vectors indexed: {vector_store.index.ntotal}")
# Out:
# Vector store built successfully.
# Total vectors indexed: 5

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# ------------------------------------------------------------------ #
# Build retriever from the vector store created in the previous cell  #
# k=2 → fetch top 2 most relevant chunks per query                    #
# ------------------------------------------------------------------ #
retriever = vector_store.as_retriever(search_kwargs={"k": 2})

# Prompt that injects retrieved chunks as context
prompt = ChatPromptTemplate.from_template("""
Answer the question using only the context below.
If the answer is not in the context, say "Sorry!I'm unable to provide you answer."

Context:
{context}

Question: {question}
""")

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Modern LCEL RAG chain — replaces RetrievalQA
qa_chain = (
    {
        "context":  retriever | format_docs,
        "question": RunnablePassthrough()
    }
    | prompt
    | model
    | StrOutputParser()
)

# Ask questions — answered from our documents, not LLM training data
questions = [
    "What is RAG and how does it reduce hallucinations?",
    "Who created LangChain and when?",
    "What is numpy used for in python?"
]

for q in questions:
    answer = qa_chain.invoke(q)
    print("Q:" ,q)
    print("A:", answer)
    print("-" * 20)
# Out:
# Q: What is RAG and how does it reduce hallucinations?
# A: RAG stands for Retrieval-Augmented Generation. It reduces hallucinations by allowing the model to answer questions grounded in real retrieved text. In a RAG pipeline, the user query is used to search for the most relevant document chunks, which are then injected into the LLM prompt as context.
# --------------------
# Q: Who created LangChain and when?
# A: LangChain was created by Harrison Chase and was first released in October 2022.
# --------------------
# Q: What is numpy used for in python?
# A: Numpy is used for fast mathematical operations on arrays and matrices in Python. It is also used in Data Science, AI, and ML, and serves as a base for libraries like Pandas and TensorFlow.
# --------------------

# %% [markdown]
# #  Real-World Use Cases

# %% [markdown]
# **se Case 1: Customer Support Chatbot with Memory**

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage

model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.5)

# Modern memory — plain list holds full conversation history
chat_history = []

support_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a friendly customer support agent for MFC Bgpm. "
               "Help with orders, returns, and product queries. Be polite and concise."),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{input}")
])

chain = support_prompt | model

def support_chat(user_input):
    chat_history.append(HumanMessage(content=user_input))
    response = chain.invoke({
        "input": user_input,
        "chat_history": chat_history
    })
    chat_history.append(AIMessage(content=response.content))
    return response.content

print("-" * 50)
print("MFC Bgpm — Customer Support Chat")
print("-" * 50)

turns = [
    "Hi, my name is Nikitha. I have placed an order 2 days ago but haven't received it yet.",
    "My order ID is FD-2026-1404.",
    "Also, what is your return policy?",
    "What was my order ID again?",    # memory test
]

for turn in turns:
    response = support_chat(turn)
    print(f"\nCustomer: {turn}")
    print(f"Support Agent: {response}")

print( "-" * 50)
# Out:
# --------------------------------------------------
# MFC Bgpm — Customer Support Chat
# --------------------------------------------------
#
# Customer: Hi, my name is Nikitha. I have placed an order 2 days ago but haven't received it yet.
# Support Agent: Hello Nikitha, thank you for reaching out to us. I'd be happy to help you with your order. Can you please provide me with your order number so I can look into this further and check the status of your delivery?
#
# Customer: My order ID is FD-2026-1404.
# Support Agent: Thank you for providing the order ID, Nikitha. I've checked on the status of your order FD-2026-1404. It seems that your order was processed and shipped out on the same day you placed it. However, it's possible that there might be a slight delay in delivery.
#
# I'd like to offer you a few options: I can try to track the shipment and provide you with an estimated delivery date, or I can assist you with resending the order if it's been lost in transit. Which option would you prefer?
#
# Customer: Also, what is your return policy?
# Support Agent: Our return policy is as follows: if you're not satisfied with your order, you can return it within 30 days of delivery. The item must be in its original condition, with all tags and packaging intact. You can initiate the return process by contacting our customer support team, and we'll guide you through the steps.
#
# Please note that you'll need to provide a reason for the return and your order number. Once we receive the returned item, we'll process a refund or exchange, depending on your preference. You can choose to receive a full refund, exchange the item for a different size or color, or receive store credit.
#
# If you'd like to return an item from your order FD-2026-1404, I can assist you with the process. Would you like me to provide more information or start the return process for you?
#
# Customer: What was my order ID again?
# Support Agent: Your order ID is FD-2026-1404, Nikitha. I have it noted in our conversation, so you don't need to worry about remembering it.
# --------------------------------------------------
